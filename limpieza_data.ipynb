# %%
import numpy as np
import pandas as pd
#NHCCPCTRL2

# %%
asma_df = pd.read_csv('./data/data_sin_asma/Datos_proyecto_II_BI_2017_sin_asma.csv', encoding="utf-8", sep = ',')
# Out:
# C:\Users\Esteban\AppData\Local\Temp\ipykernel_72172\4020366015.py:1: DtypeWarning: Columns (12,145,146,147,280,285,295,296,297,304,379,380,381,382,383,469,470,495,496,498,499,500,501,507,508,509,510,511,512,513) have mixed types. Specify dtype option on import or set low_memory=False.
#   asma_df = pd.read_csv('./data/data_sin_asma/Datos_proyecto_II_BI_2017_sin_asma.csv', encoding="utf-8", sep = ',')

# %%
asma_df.shape
# Out:
# (315225, 552)

# %%
asma_df.head(5)
# Out:
#    Unnamed: 0  DIRECTORIO  DIRECTORIO_HOG  DIRECTORIO_PER  SECUENCIA
# 0           1      101000         1010001        10100011          1  \
# 1           2      101000         1010001        10100012          1
# 2           3      101000         1010001        10100013          1
# 3           4      101001         1010011        10100111          1
# 4           5      101001         1010011        10100112          1
#
#    SECUENCIA_P  ORDEN             NVCAP99  DPTOMPIO  CLASE  ...  NPCHP34
# 0            1      1  03SEP2017:00:00:00     11001      1  ...      NaN  \
# 1            1      1  03SEP2017:00:00:00     11001      1  ...      NaN
# 2            1      1  03SEP2017:00:00:00     11001      1  ...      NaN
# 3            1      1  03SEP2017:00:00:00     11001      1  ...      NaN
# 4            1      1  03SEP2017:00:00:00     11001      1  ...      NaN
#
#    NPCHP34A NPCHP35A  NPCHP35B  NPCHP35C  NPCHP35D  NPCHP35E  NPCHP35F
# ...
